# %%
client_id = 'f476e97e-a6eb-403d-8456-be18142870f4'
client_secret = 'qst633yx7w'
ruri = 'http://127.0.0.1:5000/'
code = '_zDosI'

# %%
auth_url = (
    "https://api.upstox.com/v2/login/authorization/dialog"
    f"?response_type=code&client_id={client_id}&redirect_uri={ruri}"
)
print(auth_url)
# Out:
# https://api.upstox.com/v2/login/authorization/dialog?response_type=code&client_id=f476e97e-a6eb-403d-8456-be18142870f4&redirect_uri=http://127.0.0.1:5000/

# %%
import requests

url = 'https://api.upstox.com/v2/login/authorization/token'

headers = {
    'accept': 'application/json',
    'Content-Type': 'application/x-www-form-urlencoded',
}

data = {
    # 👇 yahan REAL authorization code paste karo
    'code': code,   
    'client_id': client_id,
    'client_secret': client_secret,
    'redirect_uri': ruri,
    'grant_type': 'authorization_code',
}

response = requests.post(url, headers=headers, data=data)

print(response.json())
# Out:
# {'email': 'paragla21@gmail.com', 'exchanges': ['BCD', 'CDS', 'BFO', 'MCX', 'NFO', 'BSE', 'NSE'], 'products': ['OCO', 'D', 'CO', 'I'], 'broker': 'UPSTOX', 'user_id': '69AKSV', 'user_name': 'PARAG VIJAY LAKHADIVE', 'order_types': ['MARKET', 'LIMIT', 'SL', 'SL-M'], 'user_type': 'individual', 'poa': False, 'ddpi': False, 'is_active': True, 'access_token': 'eyJ0eXAiOiJKV1QiLCJrZXlfaWQiOiJza192MS4wIiwiYWxnIjoiSFMyNTYifQ.eyJzdWIiOiI2OUFLU1YiLCJqdGkiOiI2OTRhYWUxNzc2MjhjMjAxYjZkNWY0ZjYiLCJpc011bHRpQ2xpZW50IjpmYWxzZSwiaXNQbHVzUGxhbiI6dHJ1ZSwiaWF0IjoxNzY2NTAxOTExLCJpc3MiOiJ1ZGFwaS1nYXRld2F5LXNlcnZpY2UiLCJleHAiOjE3NjY1MjcyMDB9.LJlghHCOGOOJxVhCvYpyGZUGfurwkpwkirQqqMoZfGk', 'extended_token': None}

# %%
user_response = response.json()
access_token = user_response['access_token']
print(access_token)
# Out:
# eyJ0eXAiOiJKV1QiLCJrZXlfaWQiOiJza192MS4wIiwiYWxnIjoiSFMyNTYifQ.eyJzdWIiOiI2OUFLU1YiLCJqdGkiOiI2OTRhYWUxNzc2MjhjMjAxYjZkNWY0ZjYiLCJpc011bHRpQ2xpZW50IjpmYWxzZSwiaXNQbHVzUGxhbiI6dHJ1ZSwiaWF0IjoxNzY2NTAxOTExLCJpc3MiOiJ1ZGFwaS1nYXRld2F5LXNlcnZpY2UiLCJleHAiOjE3NjY1MjcyMDB9.LJlghHCOGOOJxVhCvYpyGZUGfurwkpwkirQqqMoZfGk
